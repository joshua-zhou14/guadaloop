# %%
# %pip install pandas
# %pip install matplotlib
# %pip install tabulate
# %pip install IPython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tabulate in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.9.0)
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: IPython in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (8.23.0)
# Requirement already satisfied: decorator in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (5.14.2)
# Requirement already satisfied: colorama in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from asttokens>=2.1.0->stack-data->IPython) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
from IPython.display import display

data = pd.read_csv('data.csv')

# %%
tmilekey = ['tmiles_2017', 'tmiles_2018', 'tmiles_2019', 'tmiles_2020', 'tmiles_2021', 'tmiles_2022', 'tmiles_2023',
            'tmiles_2025', 'tmiles_2030', 'tmiles_2035', 'tmiles_2040', 'tmiles_2045', 'tmiles_2050']
tmile = []
for i in range(0, len(tmilekey)):
    tmile.append(0)

tonkey = ['tons_2017', 'tons_2018', 'tons_2019', 'tons_2020', 'tons_2021', 'tons_2022', 'tons_2023',
            'tons_2025', 'tons_2030', 'tons_2035', 'tons_2040', 'tons_2045', 'tons_2050']
tons = []
commodityout = []
for i in range(0, len(tonkey)):
    tons.append(0)
    commodityout.append({})

commoditydict = {}

with open('commodity.txt') as f:
    lines = f.readlines()
    for line in lines:
        temp = line.split(',')
        commoditydict[int(temp[0])] = temp[1].strip()
        for i in range(0, len(commodityout)):
            commodityout[i][temp[1].strip()] = 0


dbandlowkey = {1: 1, 2: 100, 3:250, 4:500, 5:750, 6:1000, 7:1500, 8:2001}
dbandhighkey = {1: 99, 2: 249, 3:499, 4:749, 5:999, 6:1499, 7:2000, 8:2001}
distbandlow = 0
distbandhigh = 0

for x in data.index:
    if x == 0:
        continue
    for i in range(0, len(tmilekey)):
        tmile[i] += data.loc[x, tmilekey[i]]
        tons[i] += data.loc[x, tonkey[i]]
        commodityout[i][commoditydict[data.loc[x, "sctg2"]]] += data.loc[x, tonkey[i]]
    distbandlow += dbandlowkey[data.loc[x,"dist_band"]]
    distbandhigh += dbandhighkey[data.loc[x,"dist_band"]]

df = pd.DataFrame({'Commodity': commoditydict.values()})

for i in range(0, len(commodityout)):
    for key in commodityout[i]:
        commodityout[i][key] = round(commodityout[i][key]/tons[i]*100,2)
    df.insert(i+1, tonkey[i][5:],  commodityout[i].values())
#tons_2023 - tons[6]
df = df.drop(df[df['2017'] < 3].index)
df.sort_values(by='2017', ascending=False, inplace=True)
display(df)
# Out:
#                                 Commodity   2017   2018   2019   2020   2021  \
# 16                               Gasoline  19.61  20.36  19.87  18.13  19.69
# 17                              Fuel oils  16.91  17.11  17.21  16.91  16.27
# 30                   Nonmetal min. prods.  10.35  10.45  10.29  10.85  10.55
# 11                                 Gravel   8.65   9.48   9.78  10.09   9.46
# 18  Natural gas and other fossil products   5.69   3.97   3.89   4.48   4.30
# 10                          Natural sands   4.31   5.37   5.71   5.03   5.60
# 40                            Waste/scrap   3.55   3.64   3.60   3.93   3.87
# 19                        Basic chemicals   3.48   2.84   2.62   2.65   2.78
# 1                           Cereal grains   3.01   1.98   2.67   2.65   2.78
#
#      2022   2023   2025   2030   2035   2040   2045   2050
# 16  20.22  18.13  17.39  15.94  14.63  13.36  12.14  11.02
# 17  17.34  16.14  15.66  14.80  14.08  13.36  12.67  12.05
# 30  10.43  10.00  10.10  10.30  10.58  10.77  10.87  10.94
# 11  10.06   9.21   9.17   9.55   9.55   9.68  10.04  10.43
# 18   4.72   6.48   6.58   6.81   7.01   7.19   7.35   7.54
# 10   4.56   4.75   5.03   5.20   5.23   5.18   5.03   4.91
# 40   3.98   3.19   3.11   3.02   2.93   2.92   2.92   2.91
# 19   2.61   3.67   4.05   4.54   5.10   5.70   6.34   6.87
# 1    1.77   2.58   2.53   2.48   2.43   2.37   2.29   2.21

# %%
average_human = 70
pod_low = 23
pod_high = 40
ton_to_kilo = 907.18474
pod_low_weight = pod_low*average_human/ton_to_kilo
pod_high_weight = pod_high*average_human/ton_to_kilo
print(str(pod_low_weight) + " " + str(pod_high_weight))

datalow = data
datahigh = data

tonkey = ['tons_2017', 'tons_2018', 'tons_2019', 'tons_2020', 'tons_2021', 'tons_2022', 'tons_2023',
            'tons_2025', 'tons_2030', 'tons_2035', 'tons_2040', 'tons_2045', 'tons_2050']

for x in datalow.index:
    if x == 0: 
        continue
    for key in tonkey:
        datalow[key] = datalow[key]/pod_low_weight
        datahigh[key] = datahigh[key]/pod_high_weight
# Out:
# 1.7747212105882644 3.086471670588286
